# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
def display_image():
    dog_img=np.array(Image.open('E://DogsVsCats//PetImages//Dog//14.jpg'))
    plt.imshow(dog_img)
    print(dog_img.shape)
    
display_image()
# Out:
# (387, 500, 3)

# %%
import os
import shutil
dataset_dir = 'E:\\DogsVsCats\\data1\\train'
base_dir = 'E:\\DogsVsCats\\dataset'

os.mkdir(base_dir)
train_dir=os.path.join(base_dir,'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)
train_cats_dir = os.path.join(train_dir, 'cats')
os.mkdir(train_cats_dir)
train_dogs_dir = os.path.join(train_dir, 'dogs')
os.mkdir(train_dogs_dir)
validation_cats_dir = os.path.join(validation_dir, 'cats')
os.mkdir(validation_cats_dir)
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
os.mkdir(validation_dogs_dir)
test_cats_dir = os.path.join(test_dir, 'cats')
os.mkdir(test_cats_dir)
test_dogs_dir = os.path.join(test_dir, 'dogs')
os.mkdir(test_dogs_dir)

# %%
fnames = ['cat.{}.jpg'.format(i) for i in range(4000)]
for fname in fnames:
    src = os.path.join(dataset_dir, fname)
    dst = os.path.join(train_cats_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['cat.{}.jpg'.format(i) for i in range(4000, 6000)]
for fname in fnames:
    src = os.path.join(dataset_dir, fname)
    dst = os.path.join(validation_cats_dir, fname)
    shutil.copyfile(src, dst)
    
fnames = ['cat.{}.jpg'.format(i) for i in range(6000,8000)]
for fname in fnames:
    src = os.path.join(dataset_dir, fname)
    dst = os.path.join(test_cats_dir, fname)
    shutil.copyfile(src, dst)

fnames = ['dog.{}.jpg'.format(i) for i in range(4000)]
for fname in fnames:
    src = os.path.join(dataset_dir, fname)
    dst = os.path.join(train_dogs_dir, fname)
    shutil.copyfile(src, dst)
    
fnames = ['dog.{}.jpg'.format(i) for i in range(4000, 6000)]
for fname in fnames:
    src = os.path.join(dataset_dir, fname)
    dst = os.path.join(validation_dogs_dir, fname)
    shutil.copyfile(src, dst)
    
fnames = ['dog.{}.jpg'.format(i) for i in range(6000, 8000)]
for fname in fnames:
    src = os.path.join(dataset_dir, fname)
    dst = os.path.join(test_dogs_dir, fname)
    shutil.copyfile(src, dst)

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import RMSprop,Adam
#from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %%
def get_model():
    model=Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu',input_shape=(64, 64, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# %%
model=get_model()
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_29 (Conv2D)           (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 29, 29, 64)        18496
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 4, 4, 128)         147584
# ...

# %%
#constructing callback to save best model to disk
from keras.callbacks import ModelCheckpoint
filepath='E:\\DogsVsCats\\model_weights.hdf5'
checkpoint = ModelCheckpoint(filepath,monitor='val_accuracy',mode='max',save_best_only=True,verbose=1)
callbacks=[checkpoint]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#creating train generator
train_path='E:\\DogsVsCats\\dataset\\train'
train_datagen = ImageDataGenerator( 
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(64,64),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 8000 images belonging to 2 classes.

# %%
#creating validation generator
validation_path='E:\\DogsVsCats\\dataset\\validation'
validation_datagen = ImageDataGenerator(rescale=1. / 255)
validation_generator = validation_datagen.flow_from_directory(
    validation_path,
    target_size=(64,64),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 4000 images belonging to 2 classes.

# %%
train_steps=train_generator.samples//32
validation_steps=validation_generator.samples//32

# %%
history=model.fit_generator(
    train_generator,
    steps_per_epoch=train_steps,
    epochs=30,
    validation_data=validation_generator,
    validation_steps=validation_steps
)
# Out:
# Epoch 1/30
# 250/250 [==============================] - 256s 1s/step - loss: 0.6613 - accuracy: 0.5894 - val_loss: 0.5980 - val_accuracy: 0.6566
# Epoch 2/30
# 250/250 [==============================] - 138s 552ms/step - loss: 0.5803 - accuracy: 0.6937 - val_loss: 0.5201 - val_accuracy: 0.7287
# Epoch 3/30
# 250/250 [==============================] - 137s 550ms/step - loss: 0.5027 - accuracy: 0.7556 - val_loss: 0.4118 - val_accuracy: 0.7789
# Epoch 4/30
# 250/250 [==============================] - 137s 547ms/step - loss: 0.4443 - accuracy: 0.7874 - val_loss: 0.4453 - val_accuracy: 0.8044
# Epoch 5/30
# 250/250 [==============================] - 137s 547ms/step - loss: 0.4162 - accuracy: 0.8057 - val_loss: 0.3268 - val_accuracy: 0.8198
# Epoch 6/30
# 250/250 [==============================] - 138s 550ms/step - loss: 0.3704 - accuracy: 0.8300 - val_loss: 0.2938 - val_accuracy: 0.8235
# Epoch 7/30
# ...

# %%
model.save('model_weights.h5')
